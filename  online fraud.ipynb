# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import scipy as sp
from tabulate import tabulate
import random

# %%
df = pd.read_csv("C:\\Users\computer\onlinefraud.csv")

# %%
df
# Out:
#          step      type      amount     nameOrig  oldbalanceOrg  \
# 0           1   PAYMENT     9839.64  C1231006815      170136.00
# 1           1   PAYMENT     1864.28  C1666544295       21249.00
# 2           1  TRANSFER      181.00  C1305486145         181.00
# 3           1  CASH_OUT      181.00   C840083671         181.00
# 4           1   PAYMENT    11668.14  C2048537720       41554.00
# ...       ...       ...         ...          ...            ...
# 6362615   743  CASH_OUT   339682.13   C786484425      339682.13
# 6362616   743  TRANSFER  6311409.28  C1529008245     6311409.28
# 6362617   743  CASH_OUT  6311409.28  C1162922333     6311409.28
# 6362618   743  TRANSFER   850002.52  C1685995037      850002.52
# 6362619   743  CASH_OUT   850002.52  C1280323807      850002.52
#
#          newbalanceOrig     nameDest  oldbalanceDest  newbalanceDest  isFraud  \
# 0             160296.36  M1979787155            0.00            0.00        0
# 1              19384.72  M2044282225            0.00            0.00        0
# 2                  0.00   C553264065            0.00            0.00        1
# 3                  0.00    C38997010        21182.00            0.00        1
# 4              29885.86  M1230701703            0.00            0.00        0
# ...                 ...          ...             ...             ...      ...
# 6362615            0.00   C776919290            0.00       339682.13        1
# 6362616            0.00  C1881841831            0.00            0.00        1
# 6362617            0.00  C1365125890        68488.84      6379898.11        1
# 6362618            0.00  C2080388513            0.00            0.00        1
# 6362619            0.00   C873221189      6510099.11      7360101.63        1
#
#          isFlaggedFraud
# 0                     0
# 1                     0
# 2                     0
# 3                     0
# 4                     0
# ...                 ...
# 6362615               0
# 6362616               0
# 6362617               0
# 6362618               0
# 6362619               0
#
# [6362620 rows x 11 columns]

# %%
df.drop('isFlaggedFraud', axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6362620 entries, 0 to 6362619
# Data columns (total 10 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   step            int64
#  1   type            object
#  2   amount          float64
#  3   nameOrig        object
#  4   oldbalanceOrg   float64
#  5   newbalanceOrig  float64
#  6   nameDest        object
#  7   oldbalanceDest  float64
#  8   newbalanceDest  float64
#  9   isFraud         int64
# dtypes: float64(5), int64(2), object(3)
# memory usage: 485.4+ MB

# %%
df.sample(5)
# Out:
#          step      type     amount     nameOrig  oldbalanceOrg  \
# 3580688   261   PAYMENT    7193.95  C1752142252      229656.00
# 3861590   283   PAYMENT    4787.83   C821427937       58833.00
# 1861214   164   CASH_IN  119453.17   C931417099           0.00
# 2645770   209  CASH_OUT   39724.04   C202226052       24139.00
# 3049955   234   CASH_IN   69564.10  C1595675504      329274.35
#
#          newbalanceOrig     nameDest  oldbalanceDest  newbalanceDest  isFraud
# 3580688       222462.05  M2136514275            0.00            0.00        0
# 3861590        54045.17  M1703683161            0.00            0.00        0
# 1861214       119453.17   C875194455       468062.70       348609.52        0
# 2645770            0.00   C852612230        25613.00            0.00        0
# 3049955       398838.45  C1423254234      1222529.46      1152965.36        0

# %%
df.isnull().sum()
# Out:
# step              0
# type              0
# amount            0
# nameOrig          0
# oldbalanceOrg     0
# newbalanceOrig    0
# nameDest          0
# oldbalanceDest    0
# newbalanceDest    0
# isFraud           0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
for col in df.columns:
    if df[col].dtype == 'float64':
        df[col] = pd.to_numeric(df[col], downcast='float')
    if df[col].dtype == 'int64':
        df[col] = pd.to_numeric(df[col], downcast='unsigned')


df['type'] = df['type'].astype('category')

# %%
sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (8,6)

# %%
df['step'].value_counts()
# Out:
# 19     51352
# 18     49579
# 187    49083
# 235    47491
# 307    46968
#        ...
# 432        4
# 706        4
# 693        4
# 112        2
# 662        2
# Name: step, Length: 743, dtype: int64

# %%
ax = sns.countplot(x='type', data=df, palette='PuBu')
for container in ax.containers:
    ax.bar_label(container)
plt.title('Count plot of transaction type')
plt.legend(bbox_to_anchor=(1.05,1), loc='upper left')
plt.ylabel('Number of transactions')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Text(0, 0.5, 'Number of transactions')

# %%
sns.kdeplot(df['amount'], linewidth=2)
plt.title('Distribution of transaction amount')
# Out:
# Text(0.5, 1.0, 'Distribution of transaction amount')

# %%
df['nameOrig'].value_counts()
# Out:
# C1902386530    3
# C363736674     3
# C545315117     3
# C724452879     3
# C1784010646    3
#               ..
# C98968405      1
# C720209255     1
# C1567523029    1
# C644777639     1
# C1280323807    1
# Name: nameOrig, Length: 6353307, dtype: int64

# %%
sns.kdeplot(df['oldbalanceOrg'], linewidth=2)
plt.title('Distribution of transaction amount')
# Out:
# Text(0.5, 1.0, 'Distribution of transaction amount')

# %%
sns.kdeplot(df['newbalanceOrig'], linewidth=2)
plt.title('Distribution of transaction amount')
# Out:
# Text(0.5, 1.0, 'Distribution of transaction amount')

# %%
df['nameDest'].value_counts()
# Out:
# C1286084959    113
# C985934102     109
# C665576141     105
# C2083562754    102
# C248609774     101
#               ...
# M1470027725      1
# M1330329251      1
# M1784358659      1
# M2081431099      1
# C2080388513      1
# Name: nameDest, Length: 2722362, dtype: int64

# %%
sns.kdeplot(df['oldbalanceDest'], linewidth=2)
plt.title('Distribution of transaction amount')
# Out:
# Text(0.5, 1.0, 'Distribution of transaction amount')

# %%
sns.kdeplot(df['newbalanceDest'], linewidth=2)
plt.title('Distribution of transaction amount')
# Out:
# Text(0.5, 1.0, 'Distribution of transaction amount')

# %%
ax = sns.countplot(x='isFraud', data=df, palette='PuBu')
for container in ax.containers:
    ax.bar_label(container)
plt.title('Count plot of fraud transaction')
plt.ylabel('Number of transactions')

del ax

# %%
fig, ax = plt.subplots(1,2,figsize=(20,5))

sns.countplot(x='type', data=df, hue='isFraud', palette='PuBu', ax=ax[0])
for container in ax[0].containers:
    ax[0].bar_label(container)
ax[0].set_title('Count plot of transaction type')
ax[0].legend(loc='best')
ax[0].set_ylabel('Number of transactions')

df2 = df.groupby(['type', 'isFraud']).size().unstack()
df2.apply(lambda x : round(x/sum(x)*100, 2), axis=1).plot(kind='barh', stacked=True, color=['lightsteelblue', 'steelblue'], ax=ax[1])
for container in ax[1].containers:
    ax[1].bar_label(container, label_type='center')
ax[1].set_title('Count plot of transaction type')
ax[1].legend(bbox_to_anchor=(1.05,1), loc='upper left')
ax[1].set_ylabel('Number of transactions')
ax[1].grid(axis='y')

# %%
df['quantity'] = pd.cut(df['amount'], 5, labels=['very low', 'low', 'moderate', 'high', 'very high'])

ax = sns.countplot(x='quantity', data=df, hue='isFraud', palette='PuBu')
for container in ax.containers:
    ax.bar_label(container)
plt.title('Count plot of amount quantity')
plt.legend(bbox_to_anchor=(1.05,1), loc='upper left')
plt.ylabel('Number of transactions')
# Out:
# Text(0, 0.5, 'Number of transactions')

# %%
df1 = df[df['isFraud']==1]
df2 = df1['step'].value_counts().head(10)
ax = df2.plot(kind='bar', color='lightsteelblue')
for container in ax.containers:
    ax.bar_label(container)
plt.title('Top 10 steps that often lead to fraudulent transactions')
plt.ylabel('Number of fraudulent transactions')
plt.xlabel('Step')
plt.grid(axis='x')

del ax, df2

# %%
df['oldbalanceOrg_amt'] = pd.cut(df['oldbalanceOrg'], 5, labels=['very low', 'low', 'moderate', 'high', 'very high'])

ax = sns.countplot(x='oldbalanceOrg_amt', data=df, hue='isFraud', palette='PuBu')
for container in ax.containers:
    ax.bar_label(container)
plt.title('Count plot of initial customers pre-transaction balance amount')
plt.legend(bbox_to_anchor=(1.05,1), loc='upper left')
plt.ylabel('Number of transactions')
plt.xlabel('Initial customers pre-transaction balance amount')
# Out:
# Text(0.5, 0, 'Initial customers pre-transaction balance amount')

# %%
# Data preprocessing
df['type'] = df['type'].map({'PAYMENT':0, 'CASH_IN':1, 'DEBIT':2, 'CASH_OUT':3, 'TRANSFER':4})

# %%
total_transactions = df.shape[0]

fraud_transaction = df[df.isFraud==1].shape[0]

fraud_percent= fraud_transaction/total_transactions * 100
fraud_percent
# Out:
# 0.12908204481801522

# %%
print('Total transactions: ',total_transactions)
print('Total fraud transactions happened: ',fraud_transaction)
print("Total fraud transaction percent: ",round(fraud_percent,2))
# Out:
# Total transactions:  6362620
# Total fraud transactions happened:  8213
# Total fraud transaction percent:  0.13

# %%
fraud_amount= df[df.isFraud==1]
fraud_amount=fraud_amount.sort_values(by=['amount'],ascending=False)
fraud_amount
# Out:
#          step  type      amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 3760283   279   NaN  10000000.0  C1214015158     10000000.0             0.0
# 5987587   409   NaN  10000000.0    C97242201     10000000.0             0.0
# 1707592   160   NaN  10000000.0   C525906402     10000000.0             0.0
# 1707591   160   NaN  10000000.0   C752627210     27670038.0      17670038.0
# 1707590   160   NaN  10000000.0  C2068007279     10000000.0             0.0
# ...       ...   ...         ...          ...            ...             ...
# 5996410   425   NaN         0.0    C69493310            0.0             0.0
# 5996408   425   NaN         0.0   C832555372            0.0             0.0
# 6362461   730   NaN         0.0   C729003789            0.0             0.0
# 6362463   730   NaN         0.0  C2088151490            0.0             0.0
# 3760289   279   NaN         0.0   C539112012            0.0             0.0
#
#             nameDest  oldbalanceDest  newbalanceDest  isFraud  quantity  \
# 3760283  C2110157840    0.000000e+00    1.000000e+07        1  very low
# 5987587   C786701128    8.496860e+03    1.000850e+07        1  very low
# 1707592    C43869769    2.145276e+06    1.214528e+07        1  very low
# 1707591  C1853789265    0.000000e+00    0.000000e+00        1  very low
# 1707590   C836488544    1.586432e+05    1.015864e+07        1  very low
# ...              ...             ...             ...      ...       ...
# 5996410   C719711728    2.921531e+06    2.921531e+06        1  very low
# 5996408  C1462759334    7.675990e+04    7.675990e+04        1  very low
# 6362461  C1388096959    1.008610e+06    1.008610e+06        1  very low
# 6362463  C1156763710    0.000000e+00    0.000000e+00        1  very low
# 3760289  C1106468520    5.385476e+05    5.385476e+05        1  very low
#
#         oldbalanceOrg_amt
# 3760283          very low
# 5987587          very low
# 1707592          very low
# 1707591          moderate
# 1707590          very low
# ...                   ...
# 5996410          very low
# 5996408          very low
# 6362461          very low
# 6362463          very low
# 3760289          very low
#
# [8213 rows x 12 columns]

# %%
fraud_amount.amount.plot(kind='hist', bins=15, figsize=(12,6), facecolor='orange',edgecolor='black')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
fraudster= df.nameDest.value_counts()
fraudster
# Out:
# C1286084959    113
# C985934102     109
# C665576141     105
# C2083562754    102
# C248609774     101
#               ...
# M1470027725      1
# M1330329251      1
# M1784358659      1
# M2081431099      1
# C2080388513      1
# Name: nameDest, Length: 2722362, dtype: int64

# %%
fraudster[:10]
# Out:
# C1286084959    113
# C985934102     109
# C665576141     105
# C2083562754    102
# C248609774     101
# C1590550415    101
# C451111351      99
# C1789550256     99
# C1360767589     98
# C1023714065     97
# Name: nameDest, dtype: int64

# %%
plt.figure(figsize=(15, 6))
sns.distplot(df['step'], bins=50)
# Out:
# C:\PerfLogs\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='step', ylabel='Density'>

# %%
# calculate correlation matrix
corr = df.corr()# plot the heatmap
sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns, annot=True, cmap='Blues' ,fmt=".3f")
# Out:
# <AxesSubplot:>
